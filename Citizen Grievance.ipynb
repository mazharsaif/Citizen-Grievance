# %% [markdown]
# ### Predict The Importance
# Human rights are basic rights that belong to people all around the world irrespective of race, color, sex, language, religion, political or other opinions, national or social origin, property, birth, etc. These rights include the right to life and liberty, freedom from slavery and torture, freedom of opinion and expression, the right to work and education, etc. It is meant to enable human beings to live with dignity, freedom, equality, justice, and peace. Human rights are essential to the full development of individuals and communities.
#
# In this problem, you are given a dataset that contains grievances of various people living in a country. Your task is to predict the importance of the grievance with respect to various articles, constitutional declarations, enforcement, resources, and so on, to help the government prioritize which ones to deal with and when.
#
#
# ### Data Description
# The dataset folder consists of the following three .csv files:
# * `train.csv` : Contains 8878 rows and 328 columns
# * `test.csv` : Contains 4760 rows and 327 columns
# * `sample_submission.csv`: 5 rows and 2 columns

# %% [markdown]
# |            Column_name            | Count |                                       Description                                       |
# |:---------------------------------:|:-----:|:---------------------------------------------------------------------------------------:|
# |               %%appno%%             |   1   | Represents   the application number                                                     |
# |            %application%            |   1   | Represents   the type of application used to file a complaint                           |
# |           %country.alpha2%          |   1   | Represents   the country code                                                           |
# |            country.name           |   1   | Represents   the country name                                                           |
# |            ()#decisiondate           |   1   | Represents   the date on which a decision was taken                                     |
# |              #docname              |   1   | Represents   the case or document name                                                  |
# |           doctypebranch           |   1   | Represents   the type of case                                                           |
# |                %ecli%               |   1   | Represents   an alphanumeric value that is used to identify a case                      |
# |          ()#introductiondate         |   1   | Represents   the start date                                                             |
# |               %itemid%              |   1   | Represents   the item ID                                                                |
# |           ()#judgementdate           |   1   | Represents   the judgment date                                                          |
# |               %kpdate%              |   1   | Represents   the closure date                                                           |
# |          %languageisocode%          |   1   | Represents   the language                                                               |
# |          %originatingbody%          |   1   | Represents   a party or body from whom the case originated                              |
# |        originatingbody_name       |   1   | Represents   the name of the party of body from whom the case originated                |
# |        %originatingbody_type%       |   1   | Represents   the type of the party of body from whom the case originated                |
# |             #parties.0             |   1   | Represents   the details of the party of body from whom the case originated             |
# |             #parties.1             |   1   | Represents   the details of the party of body from whom the case originated             |
# |             #parties.2             |   1   | Represents   the details of the party of body from whom the case originated             |
# |                rank               |   1   | Represents   the rank (0-10000) of officials (rank of an official increases with value) |
# |            #respondent.0           |   1   | Represents   a respondent information                                                   |
# |            #respondent.1           |   1   | Represents   a respondent information                                                   |
# |            #respondent.2           |   1   | Represents   a respondent information                                                   |
# |            #respondent.3           |   1   | Represents   a respondent information                                                   |
# |            #respondent.4           |   1   | Represents   a respondent information                                                   |
# |         #respondentOrderEng        |   1   | Represents   a respondent information                                                   |
# |          separateopinion          |   1   | Represents   the opinion on a case                                                      |
# |            %sharepointid%           |   1   | Represents   the ID of an opinion                                                       |
# |          ()#typedescription          |   1   | Represents   a type_description {12- 19}                                                |
# |            #issue.{0-26}           |   27  | Represents   the description with respect to an issue                                   |
# |          #article={number}         |   47  | Represents   the type of article with respect to a case                                 |
# |    %documentcollectionid=CASELAW%   |   1   | Represents   a document category of a case                                              |
# |   %documentcollectionid=JUDGMENTS% |   1   | Represents   a document category of a case                                              |
# |    documentcollectionid=CHAMBER   |   1   | Represents   a document category of a case                                              |
# |      %documentcollectionid=ENG%     |   1   | Represents   a document category of a case                                              |
# |   documentcollectionid=COMMITTEE  |   1   | Represents   a document category of a case                                              |
# | documentcollectionid=GRANDCHAMBER |   1   | Represents   a document category of a case                                              |
# |       #applicability={number}      |  61   | Represents   the applicability of a case                                                |
# |         #ccl_article={Type}        |  25   | Represents   the reliability of a CCL article type                                      |
# |        #paragraphs={number}        |  132  | Represents   the reliability to a paragraph                                             |
# |             importance            |   1   | Represents   the importance (0-5)                                                       |

# %% [markdown]
# ## EDA
#
# * `kpdate` = `judgementdate`
# * `application` is **WORD** for all
# * `country.alpha2` and `country.name` is a one-one mapping
# * `decisiondate` and `judgementdate` difference could be used as a feature
# * `docname` 98%unique
# * `doctypebrance` avg `importance`: chamber: committee: grandchamber::3.5:4:1.2
# * All in chamber hve value 4
# * `ecli`& `itemid` is unique, no missing
# * `introductiondate` and `decisiondate` have same indices for missing values, can create a feature by difference
# * `languageisocode` is ENG for all
# * `originatingbody` rearrange encoding to start with 1 or use`originatingbody_name`
# * `originatingbody_type` = **Court** for all
# * `rank` high rank people can have high importance 3,4, while lower ranks have spread out imp
# * `respondent`
#     * 0 has 46 entries
#     * 1 has 14 entries
#     * 2,3,4 has 1 entry each
#
# * `respondentOrderEng` some order, but explore the meaning
# * `separateopinion` has some information True/False
# * `sharepointId` all unique, explore or delete
# * `typedescription` 5unique, one only has 1entry, different averages for importance
# * `documentcollectionId=CASELAW` `documentcollectionId=JUDGEMENTS` `documentcollectionId=ENG` all same 1 value
# #### see article later, many could be redundant
# * `article=3` 2categories, exactly same avg importance
# * `article=6` 2categories, very similar avg importance
# *
# * `article=10`
#
# ### applicability has few with only 1 same value everywhere
# *

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint

import os
        
pd.set_option('display.max_rows', 350)

# %%
df = pd.read_csv('train.csv', low_memory=False, parse_dates=['decisiondate', 'introductiondate', 'judgementdate', 'kpdate'])
test = pd.read_csv('test.csv', low_memory=False, parse_dates=['decisiondate', 'introductiondate', 'judgementdate', 'kpdate'])

# %%
df.importance.dtype
# Out:
# dtype('int64')

# %%
meta = pd.DataFrame(df.columns[:-1], columns=['Columns'])
meta['unique'] = meta['Columns'].apply(lambda x: df[x].nunique())
meta['null'] = meta['Columns'].apply(lambda x: df[x].isna().sum())

# %%
meta['unique_test'] = meta['Columns'].apply(lambda x: test[x].nunique())
meta['null_test'] = meta['Columns'].apply(lambda x: test[x].isna().sum())

# %%
meta.sort_values(['null', 'unique'], ascending=[True, True])
# Out:
#                                Columns  unique  null  unique_test  null_test
# 1                          application       1     0            1          0
# 39                     languageisocode       1     0            1          0
# 42                originatingbody_type       1     0            1          0
# 103       documentcollectionid=CASELAW       1     0            1          0
# 104     documentcollectionid=JUDGMENTS       1     0            1          0
# 106           documentcollectionid=ENG       1     0            1          0
# 134                   applicability=51       1     0            2          0
# 137                    applicability=7       1     0            2          0
# 140                   applicability=28       1     0            2          0
# 141                   applicability=29       1     0            2          0
# 142                   applicability=31       1     0            2          0
# 151                   applicability=19       1     0            2          0
# 152                   applicability=40       1     0            2          0
# 156                   applicability=34       1     0            2          0
# 159                   applicability=27       1     0            2          0
# 161                   applicability=64       1     0            2          0
# 165                    applicability=4       1     0            2          0
# 167                   applicability=77       1     0            2          0
# 270                     paragraphs=7-2       1     0            2          0
# 290                    paragraphs=28-3       1     0            2          0
# 296                  paragraphs=27-1-b       1     0            2          0
# 298                    paragraphs=32-2       1     0            2          0
# 301                    paragraphs=46-4       1     0            2          0
# 53                     separateopinion       2     0            2          0
# 56                           article=3       2     0            2          0
# 57                           article=6       2     0            2          0
# 58                          article=P1       2     0            2          0
# 59                           article=5       2     0            2          0
# 60                           article=8       2     0            2          0
# 61                          article=13       2     0            2          0
# 62                          article=10       2     0            2          0
# 63                           article=2       2     0            2          0
# 64                          article=34       2     0            2          0
# 65                          article=41       2     0            2          0
# 66                          article=38       2     0            2          0
# 67                          article=35       2     0            2          0
# 68                           article=4       2     0            2          0
# 69                          article=29       2     0            2          0
# 70                          article=14       2     0            2          0
# 71                         article=P12       2     0            2          0
# 72                           article=9       2     0            2          0
# 73                           article=1       2     0            2          0
# 74                          article=11       2     0            2          0
# 75                          article=46       2     0            2          0
# 76                          article=P4       2     0            2          0
# 77                          article=17       2     0            2          0
# 78                          article=18       2     0            2          0
# 79                           article=7       2     0            2          0
# 80                            article=       2     0            2          0
# 81                          article=37       2     0            2          0
# 82                          article=P7       2     0            2          0
# 83                          article=57       2     0            2          0
# 84                          article=26       2     0            2          0
# 85                          article=27       2     0            2          0
# 86                          article=36       2     0            2          0
# 87                          article=30       2     0            2          0
# 88                          article=12       2     0            2          0
# 89                          article=56       2     0            2          0
# 90                          article=39       2     0            2          0
# 91                          article=15       2     0            2          0
# 92                          article=25       2     0            2          0
# 93                          article=P6       2     0            2          0
# 94                          article=19       2     0            2          0
# 95                          article=32       2     0            2          0
# 96                          article=33       2     0            1          0
# 97                          article=53       2     0            2          0
# 98                          article=28       2     0            2          0
# 99                          article=43       2     0            2          0
# 100                         article=52       2     0            1          0
# 101                        article=P13       2     0            1          0
# 102                         article=16       2     0            2          0
# 105       documentcollectionid=CHAMBER       2     0            2          0
# 107     documentcollectionid=COMMITTEE       2     0            2          0
# 108  documentcollectionid=GRANDCHAMBER       2     0            2          0
# 109                     applicability=       2     0            2          0
# 110                   applicability=36       2     0            2          0
# 111                   applicability=43       2     0            2          0
# 112                   applicability=41       2     0            2          0
# 113                   applicability=55       2     0            2          0
# 114                    applicability=3       2     0            2          0
# 115                   applicability=22       2     0            1          0
# 116                   applicability=60       2     0            2          0
# 117                   applicability=58       2     0            2          0
# 118                   applicability=25       2     0            2          0
# 119                   applicability=47       2     0            2          0
# 120                   applicability=12       2     0            2          0
# 121                   applicability=38       2     0            2          0
# 122                   applicability=20       2     0            2          0
# 123                   applicability=18       2     0            2          0
# 124                   applicability=24       2     0            2          0
# 125                   applicability=62       2     0            2          0
# 126                   applicability=21       2     0            2          0
# 127                   applicability=23       2     0            2          0
# 128                    applicability=8       2     0            2          0
# 129                   applicability=26       2     0            2          0
# 130                   applicability=53       2     0            2          0
# 131                   applicability=15       2     0            1          0
# 132                   applicability=48       2     0            2          0
# 133                   applicability=14       2     0            2          0
# 135                   applicability=13       2     0            2          0
# 136                    applicability=5       2     0            2          0
# 138                   applicability=50       2     0            1          0
# 139                   applicability=52       2     0            2          0
# 143                    applicability=6       2     0            1          0
# 144                   applicability=81       2     0            1          0
# 145                   applicability=66       2     0            1          0
# 146                   applicability=49       2     0            1          0
# 147                   applicability=33       2     0            2          0
# 148                   applicability=63       2     0            1          0
# 149                   applicability=68       2     0            1          0
# 150                   applicability=46       2     0            1          0
# 153                   applicability=17       2     0            2          0
# 154                   applicability=32       2     0            2          0
# 155                   applicability=72       2     0            2          0
# 157                   applicability=35       2     0            1          0
# 158                   applicability=54       2     0            1          0
# 160                   applicability=16       2     0            1          0
# 162                   applicability=57       2     0            1          0
# 163                   applicability=56       2     0            2          0
# 164                    applicability=2       2     0            1          0
# 166                   applicability=67       2     0            1          0
# 168                   applicability=71       2     0            1          0
# 169                   applicability=59       2     0            1          0
# 170                       paragraphs=3       2     0            2          0
# 171                       paragraphs=6       2     0            2          0
# 172                     paragraphs=6-1       2     0            2          0
# 173                   paragraphs=6-3-c       2     0            2          0
# 174                    paragraphs=P1-3       2     0            2          0
# 175                       paragraphs=5       2     0            2          0
# 176                     paragraphs=5-1       2     0            2          0
# 177                    paragraphs=P1-1       2     0            2          0
# 178                       paragraphs=8       2     0            2          0
# 179                     paragraphs=8-1       2     0            2          0
# 180                      paragraphs=13       2     0            2          0
# 181                      paragraphs=10       2     0            2          0
# 182                    paragraphs=10-2       2     0            2          0
# 183                    paragraphs=10-1       2     0            2          0
# 184                    paragraphs=35-1       2     0            2          0
# 185                       paragraphs=2       2     0            2          0
# 186                     paragraphs=2-1       2     0            2          0
# 187                      paragraphs=34       2     0            2          0
# 188                      paragraphs=41       2     0            2          0
# 189                      paragraphs=38       2     0            2          0
# 190                      paragraphs=35       2     0            2          0
# 191                     paragraphs=8-2       2     0            2          0
# 192                  paragraphs=35-3-a       2     0            2          0
# 193                    paragraphs=29-3       2     0            2          0
# 194                       paragraphs=4       2     0            2          0
# 195                      paragraphs=29       2     0            2          0
# 196                  paragraphs=P1-1-1       2     0            2          0
# 197                   paragraphs=5-1-e       2     0            2          0
# 198                     paragraphs=6-2       2     0            2          0
# 199                   paragraphs=5-1-c       2     0            2          0
# 200                      paragraphs=14       2     0            2          0
# 201                    paragraphs=35-3       2     0            2          0
# 202                   paragraphs=6-3-d       2     0            2          0
# 203                   paragraphs=5-1-b       2     0            2          0
# 204                     paragraphs=5-5       2     0            2          0
# 205                   paragraphs=P12-1       2     0            2          0
# 206                    paragraphs=11-1       2     0            2          0
# 207                    paragraphs=11-2       2     0            2          0
# 208                       paragraphs=9       2     0            2          0
# 209                     paragraphs=9-1       2     0            2          0
# 210                       paragraphs=1       2     0            2          0
# 211                      paragraphs=11       2     0            2          0
# 212                     paragraphs=6-3       2     0            2          0
# 213                     paragraphs=5-3       2     0            2          0
# 214                     paragraphs=5-4       2     0            2          0
# 215                      paragraphs=46       2     0            2          0
# 216                    paragraphs=46-2       2     0            2          0
# 217                   paragraphs=5-1-a       2     0            2          0
# 218                    paragraphs=P4-2       2     0            2          0
# 219                  paragraphs=P4-2-2       2     0            2          0
# 220                      paragraphs=17       2     0            2          0
# 221                      paragraphs=18       2     0            2          0
# 222                       paragraphs=7       2     0            2          0
# 223                     paragraphs=7-1       2     0            2          0
# 224                        paragraphs=       2     0            2          0
# 225                   paragraphs=4-3-d       2     0            2          0
# 226                     paragraphs=4-2       2     0            2          0
# 227                   paragraphs=6-3-e       2     0            2          0
# 228                     paragraphs=9-2       2     0            2          0
# 229                  paragraphs=P1-1-2       2     0            2          0
# 230                  paragraphs=P4-2-1       2     0            2          0
# 231                  paragraphs=37-1-c       2     0            2          0
# 232                      paragraphs=37       2     0            2          0
# 233                    paragraphs=P7-4       2     0            2          0
# 234                     paragraphs=4-1       2     0            2          0
# 235                      paragraphs=57       2     0            2          0
# 236                   paragraphs=6-3-b       2     0            2          0
# 237                  paragraphs=35-3-b       2     0            2          0
# 238                   paragraphs=5-1-f       2     0            2          0
# 239                    paragraphs=35-4       2     0            2          0
# 240                  paragraphs=P4-2-3       2     0            2          0
# 241                     paragraphs=2-2       2     0            2          0
# 242                      paragraphs=26       2     0            2          0
# 243                    paragraphs=27-2       2     0            1          0
# 244                      paragraphs=27       2     0            2          0
# 245                      paragraphs=36       2     0            2          0
# 246                    paragraphs=36-1       2     0            2          0
# 247                    paragraphs=37-1       2     0            2          0
# 248                    paragraphs=P7-2       2     0            2          0
# 249                    paragraphs=35-2       2     0            1          0
# 250                   paragraphs=5-1-d       2     0            2          0
# 251                   paragraphs=6-3-a       2     0            2          0
# 252                      paragraphs=30       2     0            2          0
# 253                    paragraphs=46-1       2     0            2          0
# 254                      paragraphs=12       2     0            2          0
# 255                    paragraphs=P7-1       2     0            2          0
# 256                  paragraphs=P7-1-1       2     0            2          0
# 257                    paragraphs=36-2       2     0            2          0
# 258                     paragraphs=5-2       2     0            2          0
# 259                    paragraphs=P1-2       2     0            2          0
# 260                    paragraphs=P1-4       2     0            1          0
# 261                    paragraphs=56-3       2     0            2          0
# 262                      paragraphs=56       2     0            2          0
# 263                    paragraphs=56-1       2     0            1          0
# 264                  paragraphs=P7-1-2       2     0            1          0
# 265                  paragraphs=38-1-a       2     0            2          0
# 266                  paragraphs=37-1-b       2     0            2          0
# 267                      paragraphs=39       2     0            2          0
# 268                    paragraphs=15-1       2     0            2          0
# 269                      paragraphs=15       2     0            2          0
# 271                    paragraphs=P4-4       2     0            2          0
# 272                    paragraphs=15-3       2     0            1          0
# 273                    paragraphs=25-1       2     0            2          0
# 274                      paragraphs=25       2     0            2          0
# 275                  paragraphs=37-1-a       2     0            2          0
# 276                    paragraphs=P6-1       2     0            2          0
# 277                    paragraphs=P7-5       2     0            2          0
# 278                      paragraphs=19       2     0            2          0
# 279                      paragraphs=32       2     0            2          0
# 280                    paragraphs=P7-3       2     0            2          0
# 281                      paragraphs=33       2     0            1          0
# 282                  paragraphs=28-1-a       2     0            1          0
# 283                      paragraphs=53       2     0            2          0
# 284                      paragraphs=28       2     0            2          0
# 285                  paragraphs=35-2-b       2     0            2          0
# 286                      paragraphs=43       2     0            2          0
# 287                   paragraphs=4-3-b       2     0            2          0
# 288                   paragraphs=4-3-a       2     0            2          0
# 289                     paragraphs=4-3       2     0            1          0
# 291                      paragraphs=52       2     0            1          0
# 292                   paragraphs=P13-1       2     0            1          0
# 293                  paragraphs=P7-4-1       2     0            1          0
# 294                      paragraphs=16       2     0            2          0
# 295                    paragraphs=P4-3       2     0            1          0
# 297                    paragraphs=29-1       2     0            1          0
# 299                    paragraphs=28-1       2     0            1          0
# 300                    paragraphs=P6-2       2     0            1          0
# 308                     ccl_article=17       2     0            1          0
# 309                     ccl_article=18       2     0            2          0
# 316                     ccl_article=46       2     0            1          0
# 323                    ccl_article=p12       2     0            1          0
# 325                     ccl_article=p6       2     0            2          0
# 6                        doctypebranch       3     0            3          0
# 302                      ccl_article=1       3     0            3          0
# 303                     ccl_article=10       3     0            3          0
# 304                     ccl_article=11       3     0            3          0
# 305                     ccl_article=12       3     0            2          0
# 306                     ccl_article=13       3     0            3          0
# 307                     ccl_article=14       3     0            3          0
# 310                      ccl_article=2       3     0            3          0
# 311                     ccl_article=25       3     0            2          0
# 312                      ccl_article=3       3     0            3          0
# 313                     ccl_article=34       3     0            3          0
# 314                     ccl_article=38       3     0            3          0
# 315                      ccl_article=4       3     0            3          0
# 317                      ccl_article=5       3     0            3          0
# 318                      ccl_article=6       3     0            3          0
# 319                      ccl_article=7       3     0            3          0
# 320                      ccl_article=8       3     0            3          0
# 321                      ccl_article=9       3     0            3          0
# 322                     ccl_article=p1       3     0            3          0
# 324                     ccl_article=p4       3     0            3          0
# 326                     ccl_article=p7       3     0            3          0
# 55                     typedescription       5     0            3          0
# 40                     originatingbody      13     0           13          0
# 41                originatingbody_name      13     0           13          0
# 2                       country.alpha2      46     0           46          0
# 3                         country.name      46     0           46          0
# 47                        respondent.0      46     0           46          0
# 52                  respondentOrderEng      46     0           46          0
# 37                       judgementdate    1906     0         1584          0
# 38                              kpdate    1906     0         1584          0
# 46                                rank    5026     0         3328          0
# 43                           parties.0    8361     0         4624          0
# 5                              docname    8682     0         4727          0
# 0                                appno    8799     0         4760          0
# 7                                 ecli    8878     0         4760          0
# 36                              itemid    8878     0         4760          0
# 54                        sharepointid    8878     0         4760          0
# 44                           parties.1      93     4           76          2
# 9                              issue.0    2061  6630         1147       3532
# 10                             issue.1    1122  7693          642       4087
# 4                         decisiondate     232  8202          182       4401
# 8                     introductiondate     511  8202          294       4400
# 21                             issue.2     608  8239          339       4402
# 29                             issue.3     348  8508          200       4553
# 30                             issue.4     205  8668          107       4653
# 31                             issue.5     120  8757           68       4692
# 32                             issue.6      77  8801           40       4720
# 33                             issue.7      53  8825           31       4729
# 48                        respondent.1      14  8841            9       4740
# 34                             issue.8      31  8847           16       4744
# 35                             issue.9      25  8853           10       4750
# 11                            issue.10      21  8857            8       4752
# 12                            issue.11      17  8861            8       4752
# 13                            issue.12      15  8863            6       4754
# 14                            issue.13      12  8866            4       4756
# 15                            issue.14      10  8868            4       4756
# 16                            issue.15       7  8871            4       4756
# 17                            issue.16       4  8874            3       4757
# 18                            issue.17       3  8875            2       4758
# 19                            issue.18       2  8876            2       4758
# 20                            issue.19       2  8876            2       4758
# 22                            issue.20       2  8876            2       4758
# 23                            issue.21       2  8876            1       4759
# 24                            issue.22       2  8876            1       4759
# 25                            issue.23       2  8876            1       4759
# 26                            issue.24       1  8877            0       4760
# 27                            issue.25       1  8877            0       4760
# 28                            issue.26       1  8877            0       4760
# 45                           parties.2       1  8877            0       4760
# 49                        respondent.2       1  8877            2       4758
# 50                        respondent.3       1  8877            1       4759
# 51                        respondent.4       1  8877            1       4759

# %% [markdown]
# ------

# %%
redundant_cols = ['application', #ALL same entries
                  'languageisocode',
                  'originatingbody_type',
                  'documentcollectionid=CASELAW',
                  'documentcollectionid=JUDGMENTS',
                  'documentcollectionid=ENG',
                  'applicability=57',
                  'applicability=7',
                  'applicability=28',
                  'applicability=29',
                  'applicability=31',
                  'applicability=19',
                  'applicability=40',
                  'applicability=34',
                  'applicability=27',
                  'applicability=64',
                  'applicability=4',
                  'applicability=77',
                  
                  
                  #kpdate=j,
                  'kpdate',
                  
                  #country.alpha2->country.name one-one mapping
                  'country.alpha2',
                  #originatingbody->originatingbody_name
                  'originatingbody',
                  #resppondent.0->country.name one-one mapping
                  'respondent.0',
                  
                  
                  #All unique values
                  'ecli',
                  'itemid',
                  'sharepointid',
                  
                  #These paracols have same entry 0 in training except 1 outlier with 1 in testing
                  'paragraphs=7-2',
                  'paragraphs=28-3',
                  'paragraphs=27-1-b',
                  'paragraphs=32-2',
                  'paragraphs=46-4',
                  
                  #
                  'respondent.2', #one entry in training
                  'respondent.3', #one entry in training
                  'respondent.4', #one entry in training

                  'appno',
                  
                  #
                  'parties.1', #generally matching Country names
                  'parties.2', #one entry in training, none in testing
                  'parties.0', #94% distinct entries, rest occur 6 times each
                  
                  'docname',#cannot encode
                  'respondent.1'
                 ]


new_features_from = ['decisiondate',
                     'introductiondate',
                    'typedescription',
                    ]

# sense_drop = ['respondent.2', #one value in training
#               'respondent.3', #one value in training
#               'respondent.4' #one value in training
#              ]

# %%
df = df.drop(redundant_cols, axis=1)
test = test.drop(redundant_cols, axis=1)

# %% [markdown]
# `respondentOrderEng` keep 10 most frequent values, rest as others

# %% [markdown]
# ### new_features
#
# `decisiondate`-`introductiondate`
# `judgementdate`-`introductiondate`or`decisiondate`

# %%
df['deci-intro'] = df['decisiondate'] - df['introductiondate']
df['deci-intro'] = df['deci-intro'].apply(lambda x: x.days)

test['deci-intro'] = test['decisiondate'] - test['introductiondate']
test['deci-intro'] = test['deci-intro'].apply(lambda x: x.days)


df['judge-intro'] = df['judgementdate'] - df['introductiondate']
df['judge-intro'] = df['judge-intro'].apply(lambda x: x.days)

test['judge-intro'] = test['judgementdate'] - test['introductiondate']
test['judge-intro'] = test['judge-intro'].apply(lambda x: x.days)


df = df.drop(['decisiondate', 'introductiondate'], axis=1)
test = test.drop(['decisiondate', 'introductiondate'], axis=1)

# %%
test['judge-intro']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 4755   NaN
# 4756   NaN
# 4757   NaN
# 4758   NaN
# 4759   NaN
# Name: judge-intro, Length: 4760, dtype: float64

# %%
df['typedescription'] = df['typedescription'].map({15:'A', 14:'B'}) # 25 rows will have nan values
test['typedescription'] = test['typedescription'].map({15:'A', 14:'B'}) # 25 rows will have nan values

# %%
groups = ['applicability','respondent', 'issue', 'article', 'ccl', 'paragraph']
groups_dict = {i:[] for i in groups}

for i in groups:
    for j in df.columns:
        if j.startswith(i):
            groups_dict[i].append(j)

# %%
groups_dict
# Out:
# {'applicability': ['applicability=',
#   'applicability=36',
#   'applicability=43',
#   'applicability=41',
#   'applicability=55',
#   'applicability=3',
#   'applicability=22',
#   'applicability=60',
#   'applicability=58',
#   'applicability=25',
#   'applicability=47',
#   'applicability=12',
#   'applicability=38',
#   'applicability=20',
#   'applicability=18',
#   'applicability=24',
#   'applicability=62',
#   'applicability=21',
#   'applicability=23',
#   'applicability=8',
#   'applicability=26',
#   'applicability=53',
#   'applicability=15',
#   'applicability=48',
#   'applicability=14',
#   'applicability=51',
#   'applicability=13',
#   'applicability=5',
#   'applicability=50',
#   'applicability=52',
#   'applicability=6',
#   'applicability=81',
#   'applicability=66',
#   'applicability=49',
#   'applicability=33',
#   'applicability=63',
#   'applicability=68',
#   'applicability=46',
#   'applicability=17',
#   'applicability=32',
#   'applicability=72',
#   'applicability=35',
#   'applicability=54',
#   'applicability=16',
#   'applicability=56',
#   'applicability=2',
#   'applicability=67',
#   'applicability=71',
#   'applicability=59'],
#  'respondent': ['respondentOrderEng'],
#  'issue': ['issue.0',
#   'issue.1',
#   'issue.10',
#   'issue.11',
#   'issue.12',
#   'issue.13',
#   'issue.14',
#   'issue.15',
#   'issue.16',
#   'issue.17',
#   'issue.18',
#   'issue.19',
#   'issue.2',
#   'issue.20',
#   'issue.21',
#   'issue.22',
#   'issue.23',
#   'issue.24',
#   'issue.25',
#   'issue.26',
#   'issue.3',
#   'issue.4',
#   'issue.5',
#   'issue.6',
#   'issue.7',
#   'issue.8',
#   'issue.9'],
#  'article': ['article=3',
#   'article=6',
#   'article=P1',
#   'article=5',
#   'article=8',
#   'article=13',
#   'article=10',
#   'article=2',
#   'article=34',
#   'article=41',
#   'article=38',
#   'article=35',
#   'article=4',
#   'article=29',
#   'article=14',
#   'article=P12',
#   'article=9',
#   'article=1',
#   'article=11',
#   'article=46',
#   'article=P4',
#   'article=17',
#   'article=18',
#   'article=7',
#   'article=',
#   'article=37',
#   'article=P7',
#   'article=57',
#   'article=26',
#   'article=27',
#   'article=36',
#   'article=30',
#   'article=12',
#   'article=56',
#   'article=39',
#   'article=15',
#   'article=25',
#   'article=P6',
#   'article=19',
#   'article=32',
#   'article=33',
#   'article=53',
#   'article=28',
#   'article=43',
#   'article=52',
#   'article=P13',
#   'article=16'],
#  'ccl': ['ccl_article=1',
#   'ccl_article=10',
#   'ccl_article=11',
#   'ccl_article=12',
#   'ccl_article=13',
#   'ccl_article=14',
#   'ccl_article=17',
#   'ccl_article=18',
#   'ccl_article=2',
#   'ccl_article=25',
#   'ccl_article=3',
#   'ccl_article=34',
#   'ccl_article=38',
#   'ccl_article=4',
#   'ccl_article=46',
#   'ccl_article=5',
#   'ccl_article=6',
#   'ccl_article=7',
#   'ccl_article=8',
#   'ccl_article=9',
#   'ccl_article=p1',
#   'ccl_article=p12',
#   'ccl_article=p4',
#   'ccl_article=p6',
#   'ccl_article=p7'],
#  'paragraph': ['paragraphs=3',
#   'paragraphs=6',
#   'paragraphs=6-1',
#   'paragraphs=6-3-c',
#   'paragraphs=P1-3',
#   'paragraphs=5',
#   'paragraphs=5-1',
#   'paragraphs=P1-1',
#   'paragraphs=8',
#   'paragraphs=8-1',
#   'paragraphs=13',
#   'paragraphs=10',
#   'paragraphs=10-2',
#   'paragraphs=10-1',
#   'paragraphs=35-1',
#   'paragraphs=2',
#   'paragraphs=2-1',
#   'paragraphs=34',
#   'paragraphs=41',
#   'paragraphs=38',
#   'paragraphs=35',
#   'paragraphs=8-2',
#   'paragraphs=35-3-a',
#   'paragraphs=29-3',
#   'paragraphs=4',
#   'paragraphs=29',
#   'paragraphs=P1-1-1',
#   'paragraphs=5-1-e',
#   'paragraphs=6-2',
#   'paragraphs=5-1-c',
#   'paragraphs=14',
#   'paragraphs=35-3',
#   'paragraphs=6-3-d',
#   'paragraphs=5-1-b',
#   'paragraphs=5-5',
#   'paragraphs=P12-1',
#   'paragraphs=11-1',
#   'paragraphs=11-2',
#   'paragraphs=9',
#   'paragraphs=9-1',
#   'paragraphs=1',
#   'paragraphs=11',
#   'paragraphs=6-3',
#   'paragraphs=5-3',
#   'paragraphs=5-4',
#   'paragraphs=46',
#   'paragraphs=46-2',
#   'paragraphs=5-1-a',
#   'paragraphs=P4-2',
#   'paragraphs=P4-2-2',
#   'paragraphs=17',
#   'paragraphs=18',
#   'paragraphs=7',
#   'paragraphs=7-1',
#   'paragraphs=',
#   'paragraphs=4-3-d',
#   'paragraphs=4-2',
#   'paragraphs=6-3-e',
#   'paragraphs=9-2',
#   'paragraphs=P1-1-2',
#   'paragraphs=P4-2-1',
#   'paragraphs=37-1-c',
#   'paragraphs=37',
#   'paragraphs=P7-4',
#   'paragraphs=4-1',
#   'paragraphs=57',
#   'paragraphs=6-3-b',
#   'paragraphs=35-3-b',
#   'paragraphs=5-1-f',
#   'paragraphs=35-4',
#   'paragraphs=P4-2-3',
#   'paragraphs=2-2',
#   'paragraphs=26',
#   'paragraphs=27-2',
#   'paragraphs=27',
#   'paragraphs=36',
#   'paragraphs=36-1',
#   'paragraphs=37-1',
#   'paragraphs=P7-2',
#   'paragraphs=35-2',
#   'paragraphs=5-1-d',
#   'paragraphs=6-3-a',
#   'paragraphs=30',
#   'paragraphs=46-1',
#   'paragraphs=12',
#   'paragraphs=P7-1',
#   'paragraphs=P7-1-1',
#   'paragraphs=36-2',
#   'paragraphs=5-2',
#   'paragraphs=P1-2',
#   'paragraphs=P1-4',
#   'paragraphs=56-3',
#   'paragraphs=56',
#   'paragraphs=56-1',
#   'paragraphs=P7-1-2',
#   'paragraphs=38-1-a',
#   'paragraphs=37-1-b',
#   'paragraphs=39',
#   'paragraphs=15-1',
#   'paragraphs=15',
#   'paragraphs=P4-4',
#   'paragraphs=15-3',
#   'paragraphs=25-1',
#   'paragraphs=25',
#   'paragraphs=37-1-a',
#   'paragraphs=P6-1',
#   'paragraphs=P7-5',
#   'paragraphs=19',
#   'paragraphs=32',
#   'paragraphs=P7-3',
#   'paragraphs=33',
#   'paragraphs=28-1-a',
#   'paragraphs=53',
#   'paragraphs=28',
#   'paragraphs=35-2-b',
#   'paragraphs=43',
#   'paragraphs=4-3-b',
#   'paragraphs=4-3-a',
#   'paragraphs=4-3',
#   'paragraphs=52',
#   'paragraphs=P13-1',
#   'paragraphs=P7-4-1',
#   'paragraphs=16',
#   'paragraphs=P4-3',
#   'paragraphs=29-1',
#   'paragraphs=28-1',
#   'paragraphs=P6-2']}

# %%
df = df.drop(groups_dict['issue'], axis=1)
test = test.drop(groups_dict['issue'], axis=1)

# %% [markdown]
# Keep highest occuring columns of 1 in article group

# %%
## Keep highest occuring columns of 1

article_df = df[groups_dict['article']]

meta_article_df = pd.DataFrame({}, index=article_df.columns)
meta_article_df=meta_article_df.reset_index()

meta_article_df['zero']=meta_article_df['index'].apply(lambda x: df[x].value_counts()[0])
meta_article_df['one']=meta_article_df['index'].apply(lambda x: df[x].value_counts()[1])

meta_article_df.sort_values('one', ascending=False)
# Out:
#           index  zero   one
# 1     article=6  3988  4890
# 9    article=41  5610  3268
# 0     article=3  7278  1600
# 2    article=P1  7304  1574
# 3     article=5  7344  1534
# 5    article=13  7408  1470
# 11   article=35  7462  1416
# 4     article=8  7846  1032
# 13   article=29  8007   871
# 7     article=2  8340   538
# 8    article=34  8344   534
# 6    article=10  8356   522
# 14   article=14  8435   443
# 18   article=11  8690   188
# 19   article=46  8744   134
# 16    article=9  8792    86
# 26   article=P7  8802    76
# 25   article=37  8807    71
# 20   article=P4  8807    71
# 23    article=7  8812    66
# 10   article=38  8826    52
# 17    article=1  8828    50
# 22   article=18  8828    50
# 21   article=17  8851    27
# 30   article=36  8853    25
# 12    article=4  8854    24
# 32   article=12  8854    24
# 24     article=  8859    19
# 27   article=57  8862    16
# 35   article=15  8865    13
# 28   article=26  8865    13
# 36   article=25  8867    11
# 31   article=30  8872     6
# 43   article=43  8873     5
# 37   article=P6  8874     4
# 15  article=P12  8874     4
# 39   article=32  8875     3
# 33   article=56  8875     3
# 34   article=39  8875     3
# 29   article=27  8875     3
# 38   article=19  8876     2
# 41   article=53  8876     2
# 42   article=28  8876     2
# 44   article=52  8876     2
# 40   article=33  8877     1
# 45  article=P13  8877     1
# 46   article=16  8877     1

# %%
df.dtypes
# Out:
# country.name                                 object
# doctypebranch                                object
# judgementdate                        datetime64[ns]
# originatingbody_name                         object
# rank                                        float64
# respondentOrderEng                            int64
# separateopinion                                bool
# typedescription                              object
# article=3                                     int64
# article=6                                     int64
# article=P1                                    int64
# article=5                                     int64
# article=8                                     int64
# article=13                                    int64
# article=10                                    int64
# article=2                                     int64
# article=34                                    int64
# article=41                                    int64
# article=38                                    int64
# article=35                                    int64
# article=4                                     int64
# article=29                                    int64
# article=14                                    int64
# article=P12                                   int64
# article=9                                     int64
# article=1                                     int64
# article=11                                    int64
# article=46                                    int64
# article=P4                                    int64
# article=17                                    int64
# article=18                                    int64
# article=7                                     int64
# article=                                      int64
# article=37                                    int64
# article=P7                                    int64
# article=57                                    int64
# article=26                                    int64
# article=27                                    int64
# article=36                                    int64
# article=30                                    int64
# article=12                                    int64
# article=56                                    int64
# article=39                                    int64
# article=15                                    int64
# article=25                                    int64
# article=P6                                    int64
# article=19                                    int64
# article=32                                    int64
# article=33                                    int64
# article=53                                    int64
# article=28                                    int64
# article=43                                    int64
# article=52                                    int64
# article=P13                                   int64
# article=16                                    int64
# documentcollectionid=CHAMBER                  int64
# documentcollectionid=COMMITTEE                int64
# documentcollectionid=GRANDCHAMBER             int64
# applicability=                                int64
# applicability=36                              int64
# applicability=43                              int64
# applicability=41                              int64
# applicability=55                              int64
# applicability=3                               int64
# applicability=22                              int64
# applicability=60                              int64
# applicability=58                              int64
# applicability=25                              int64
# applicability=47                              int64
# applicability=12                              int64
# applicability=38                              int64
# applicability=20                              int64
# applicability=18                              int64
# applicability=24                              int64
# applicability=62                              int64
# applicability=21                              int64
# applicability=23                              int64
# applicability=8                               int64
# applicability=26                              int64
# applicability=53                              int64
# applicability=15                              int64
# applicability=48                              int64
# applicability=14                              int64
# applicability=51                              int64
# applicability=13                              int64
# applicability=5                               int64
# applicability=50                              int64
# applicability=52                              int64
# applicability=6                               int64
# applicability=81                              int64
# applicability=66                              int64
# applicability=49                              int64
# applicability=33                              int64
# applicability=63                              int64
# applicability=68                              int64
# applicability=46                              int64
# applicability=17                              int64
# applicability=32                              int64
# applicability=72                              int64
# applicability=35                              int64
# applicability=54                              int64
# applicability=16                              int64
# applicability=56                              int64
# applicability=2                               int64
# applicability=67                              int64
# applicability=71                              int64
# applicability=59                              int64
# paragraphs=3                                  int64
# paragraphs=6                                  int64
# paragraphs=6-1                                int64
# paragraphs=6-3-c                              int64
# paragraphs=P1-3                               int64
# paragraphs=5                                  int64
# paragraphs=5-1                                int64
# paragraphs=P1-1                               int64
# paragraphs=8                                  int64
# paragraphs=8-1                                int64
# paragraphs=13                                 int64
# paragraphs=10                                 int64
# paragraphs=10-2                               int64
# paragraphs=10-1                               int64
# paragraphs=35-1                               int64
# paragraphs=2                                  int64
# paragraphs=2-1                                int64
# paragraphs=34                                 int64
# paragraphs=41                                 int64
# paragraphs=38                                 int64
# paragraphs=35                                 int64
# paragraphs=8-2                                int64
# paragraphs=35-3-a                             int64
# paragraphs=29-3                               int64
# paragraphs=4                                  int64
# paragraphs=29                                 int64
# paragraphs=P1-1-1                             int64
# paragraphs=5-1-e                              int64
# paragraphs=6-2                                int64
# paragraphs=5-1-c                              int64
# paragraphs=14                                 int64
# paragraphs=35-3                               int64
# paragraphs=6-3-d                              int64
# paragraphs=5-1-b                              int64
# paragraphs=5-5                                int64
# paragraphs=P12-1                              int64
# paragraphs=11-1                               int64
# paragraphs=11-2                               int64
# paragraphs=9                                  int64
# paragraphs=9-1                                int64
# paragraphs=1                                  int64
# paragraphs=11                                 int64
# paragraphs=6-3                                int64
# paragraphs=5-3                                int64
# paragraphs=5-4                                int64
# paragraphs=46                                 int64
# paragraphs=46-2                               int64
# paragraphs=5-1-a                              int64
# paragraphs=P4-2                               int64
# paragraphs=P4-2-2                             int64
# paragraphs=17                                 int64
# paragraphs=18                                 int64
# paragraphs=7                                  int64
# paragraphs=7-1                                int64
# paragraphs=                                   int64
# paragraphs=4-3-d                              int64
# paragraphs=4-2                                int64
# paragraphs=6-3-e                              int64
# paragraphs=9-2                                int64
# paragraphs=P1-1-2                             int64
# paragraphs=P4-2-1                             int64
# paragraphs=37-1-c                             int64
# paragraphs=37                                 int64
# paragraphs=P7-4                               int64
# paragraphs=4-1                                int64
# paragraphs=57                                 int64
# paragraphs=6-3-b                              int64
# paragraphs=35-3-b                             int64
# paragraphs=5-1-f                              int64
# paragraphs=35-4                               int64
# paragraphs=P4-2-3                             int64
# paragraphs=2-2                                int64
# paragraphs=26                                 int64
# paragraphs=27-2                               int64
# paragraphs=27                                 int64
# paragraphs=36                                 int64
# paragraphs=36-1                               int64
# paragraphs=37-1                               int64
# paragraphs=P7-2                               int64
# paragraphs=35-2                               int64
# paragraphs=5-1-d                              int64
# paragraphs=6-3-a                              int64
# paragraphs=30                                 int64
# paragraphs=46-1                               int64
# paragraphs=12                                 int64
# paragraphs=P7-1                               int64
# paragraphs=P7-1-1                             int64
# paragraphs=36-2                               int64
# paragraphs=5-2                                int64
# paragraphs=P1-2                               int64
# paragraphs=P1-4                               int64
# paragraphs=56-3                               int64
# paragraphs=56                                 int64
# paragraphs=56-1                               int64
# paragraphs=P7-1-2                             int64
# paragraphs=38-1-a                             int64
# paragraphs=37-1-b                             int64
# paragraphs=39                                 int64
# paragraphs=15-1                               int64
# paragraphs=15                                 int64
# paragraphs=P4-4                               int64
# paragraphs=15-3                               int64
# paragraphs=25-1                               int64
# paragraphs=25                                 int64
# paragraphs=37-1-a                             int64
# paragraphs=P6-1                               int64
# paragraphs=P7-5                               int64
# paragraphs=19                                 int64
# paragraphs=32                                 int64
# paragraphs=P7-3                               int64
# paragraphs=33                                 int64
# paragraphs=28-1-a                             int64
# paragraphs=53                                 int64
# paragraphs=28                                 int64
# paragraphs=35-2-b                             int64
# paragraphs=43                                 int64
# paragraphs=4-3-b                              int64
# paragraphs=4-3-a                              int64
# paragraphs=4-3                                int64
# paragraphs=52                                 int64
# paragraphs=P13-1                              int64
# paragraphs=P7-4-1                             int64
# paragraphs=16                                 int64
# paragraphs=P4-3                               int64
# paragraphs=29-1                               int64
# paragraphs=28-1                               int64
# paragraphs=P6-2                               int64
# ccl_article=1                                 int64
# ccl_article=10                                int64
# ccl_article=11                                int64
# ccl_article=12                                int64
# ccl_article=13                                int64
# ccl_article=14                                int64
# ccl_article=17                                int64
# ccl_article=18                                int64
# ccl_article=2                                 int64
# ccl_article=25                                int64
# ccl_article=3                                 int64
# ccl_article=34                                int64
# ccl_article=38                                int64
# ccl_article=4                                 int64
# ccl_article=46                                int64
# ccl_article=5                                 int64
# ccl_article=6                                 int64
# ccl_article=7                                 int64
# ccl_article=8                                 int64
# ccl_article=9                                 int64
# ccl_article=p1                                int64
# ccl_article=p12                               int64
# ccl_article=p4                                int64
# ccl_article=p6                                int64
# ccl_article=p7                                int64
# importance                                    int64
# deci-intro                                  float64
# judge-intro                                 float64
# dtype: object

# %%
test.dtypes
# Out:
# country.name                                 object
# doctypebranch                                object
# judgementdate                        datetime64[ns]
# originatingbody_name                         object
# rank                                        float64
# respondentOrderEng                            int64
# separateopinion                                bool
# typedescription                              object
# article=3                                     int64
# article=6                                     int64
# article=P1                                    int64
# article=5                                     int64
# article=8                                     int64
# article=13                                    int64
# article=10                                    int64
# article=2                                     int64
# article=34                                    int64
# article=41                                    int64
# article=38                                    int64
# article=35                                    int64
# article=4                                     int64
# article=29                                    int64
# article=14                                    int64
# article=P12                                   int64
# article=9                                     int64
# article=1                                     int64
# article=11                                    int64
# article=46                                    int64
# article=P4                                    int64
# article=17                                    int64
# article=18                                    int64
# article=7                                     int64
# article=                                      int64
# article=37                                    int64
# article=P7                                    int64
# article=57                                    int64
# article=26                                    int64
# article=27                                    int64
# article=36                                    int64
# article=30                                    int64
# article=12                                    int64
# article=56                                    int64
# article=39                                    int64
# article=15                                    int64
# article=25                                    int64
# article=P6                                    int64
# article=19                                    int64
# article=32                                    int64
# article=33                                    int64
# article=53                                    int64
# article=28                                    int64
# article=43                                    int64
# article=52                                    int64
# article=P13                                   int64
# article=16                                    int64
# documentcollectionid=CHAMBER                  int64
# documentcollectionid=COMMITTEE                int64
# documentcollectionid=GRANDCHAMBER             int64
# applicability=                                int64
# applicability=36                              int64
# applicability=43                              int64
# applicability=41                              int64
# applicability=55                              int64
# applicability=3                               int64
# applicability=22                              int64
# applicability=60                              int64
# applicability=58                              int64
# applicability=25                              int64
# applicability=47                              int64
# applicability=12                              int64
# applicability=38                              int64
# applicability=20                              int64
# applicability=18                              int64
# applicability=24                              int64
# applicability=62                              int64
# applicability=21                              int64
# applicability=23                              int64
# applicability=8                               int64
# applicability=26                              int64
# applicability=53                              int64
# applicability=15                              int64
# applicability=48                              int64
# applicability=14                              int64
# applicability=51                              int64
# applicability=13                              int64
# applicability=5                               int64
# applicability=50                              int64
# applicability=52                              int64
# applicability=6                               int64
# applicability=81                              int64
# applicability=66                              int64
# applicability=49                              int64
# applicability=33                              int64
# applicability=63                              int64
# applicability=68                              int64
# applicability=46                              int64
# applicability=17                              int64
# applicability=32                              int64
# applicability=72                              int64
# applicability=35                              int64
# applicability=54                              int64
# applicability=16                              int64
# applicability=56                              int64
# applicability=2                               int64
# applicability=67                              int64
# applicability=71                              int64
# applicability=59                              int64
# paragraphs=3                                  int64
# paragraphs=6                                  int64
# paragraphs=6-1                                int64
# paragraphs=6-3-c                              int64
# paragraphs=P1-3                               int64
# paragraphs=5                                  int64
# paragraphs=5-1                                int64
# paragraphs=P1-1                               int64
# paragraphs=8                                  int64
# paragraphs=8-1                                int64
# paragraphs=13                                 int64
# paragraphs=10                                 int64
# paragraphs=10-2                               int64
# paragraphs=10-1                               int64
# paragraphs=35-1                               int64
# paragraphs=2                                  int64
# paragraphs=2-1                                int64
# paragraphs=34                                 int64
# paragraphs=41                                 int64
# paragraphs=38                                 int64
# paragraphs=35                                 int64
# paragraphs=8-2                                int64
# paragraphs=35-3-a                             int64
# paragraphs=29-3                               int64
# paragraphs=4                                  int64
# paragraphs=29                                 int64
# paragraphs=P1-1-1                             int64
# paragraphs=5-1-e                              int64
# paragraphs=6-2                                int64
# paragraphs=5-1-c                              int64
# paragraphs=14                                 int64
# paragraphs=35-3                               int64
# paragraphs=6-3-d                              int64
# paragraphs=5-1-b                              int64
# paragraphs=5-5                                int64
# paragraphs=P12-1                              int64
# paragraphs=11-1                               int64
# paragraphs=11-2                               int64
# paragraphs=9                                  int64
# paragraphs=9-1                                int64
# paragraphs=1                                  int64
# paragraphs=11                                 int64
# paragraphs=6-3                                int64
# paragraphs=5-3                                int64
# paragraphs=5-4                                int64
# paragraphs=46                                 int64
# paragraphs=46-2                               int64
# paragraphs=5-1-a                              int64
# paragraphs=P4-2                               int64
# paragraphs=P4-2-2                             int64
# paragraphs=17                                 int64
# paragraphs=18                                 int64
# paragraphs=7                                  int64
# paragraphs=7-1                                int64
# paragraphs=                                   int64
# paragraphs=4-3-d                              int64
# paragraphs=4-2                                int64
# paragraphs=6-3-e                              int64
# paragraphs=9-2                                int64
# paragraphs=P1-1-2                             int64
# paragraphs=P4-2-1                             int64
# paragraphs=37-1-c                             int64
# paragraphs=37                                 int64
# paragraphs=P7-4                               int64
# paragraphs=4-1                                int64
# paragraphs=57                                 int64
# paragraphs=6-3-b                              int64
# paragraphs=35-3-b                             int64
# paragraphs=5-1-f                              int64
# paragraphs=35-4                               int64
# paragraphs=P4-2-3                             int64
# paragraphs=2-2                                int64
# paragraphs=26                                 int64
# paragraphs=27-2                               int64
# paragraphs=27                                 int64
# paragraphs=36                                 int64
# paragraphs=36-1                               int64
# paragraphs=37-1                               int64
# paragraphs=P7-2                               int64
# paragraphs=35-2                               int64
# paragraphs=5-1-d                              int64
# paragraphs=6-3-a                              int64
# paragraphs=30                                 int64
# paragraphs=46-1                               int64
# paragraphs=12                                 int64
# paragraphs=P7-1                               int64
# paragraphs=P7-1-1                             int64
# paragraphs=36-2                               int64
# paragraphs=5-2                                int64
# paragraphs=P1-2                               int64
# paragraphs=P1-4                               int64
# paragraphs=56-3                               int64
# paragraphs=56                                 int64
# paragraphs=56-1                               int64
# paragraphs=P7-1-2                             int64
# paragraphs=38-1-a                             int64
# paragraphs=37-1-b                             int64
# paragraphs=39                                 int64
# paragraphs=15-1                               int64
# paragraphs=15                                 int64
# paragraphs=P4-4                               int64
# paragraphs=15-3                               int64
# paragraphs=25-1                               int64
# paragraphs=25                                 int64
# paragraphs=37-1-a                             int64
# paragraphs=P6-1                               int64
# paragraphs=P7-5                               int64
# paragraphs=19                                 int64
# paragraphs=32                                 int64
# paragraphs=P7-3                               int64
# paragraphs=33                                 int64
# paragraphs=28-1-a                             int64
# paragraphs=53                                 int64
# paragraphs=28                                 int64
# paragraphs=35-2-b                             int64
# paragraphs=43                                 int64
# paragraphs=4-3-b                              int64
# paragraphs=4-3-a                              int64
# paragraphs=4-3                                int64
# paragraphs=52                                 int64
# paragraphs=P13-1                              int64
# paragraphs=P7-4-1                             int64
# paragraphs=16                                 int64
# paragraphs=P4-3                               int64
# paragraphs=29-1                               int64
# paragraphs=28-1                               int64
# paragraphs=P6-2                               int64
# ccl_article=1                                 int64
# ccl_article=10                                int64
# ccl_article=11                                int64
# ccl_article=12                                int64
# ccl_article=13                                int64
# ccl_article=14                                int64
# ccl_article=17                                int64
# ccl_article=18                                int64
# ccl_article=2                                 int64
# ccl_article=25                                int64
# ccl_article=3                                 int64
# ccl_article=34                                int64
# ccl_article=38                                int64
# ccl_article=4                                 int64
# ccl_article=46                                int64
# ccl_article=5                                 int64
# ccl_article=6                                 int64
# ccl_article=7                                 int64
# ccl_article=8                                 int64
# ccl_article=9                                 int64
# ccl_article=p1                                int64
# ccl_article=p12                               int64
# ccl_article=p4                                int64
# ccl_article=p6                                int64
# ccl_article=p7                                int64
# deci-intro                                  float64
# judge-intro                                 float64
# dtype: object

# %%
labels = df.pop('importance')

# %%
d = df.fillna(0)
t = test.fillna(0)

# %%
cat_cols = [
    'country.name',
    'doctypebranch',
    'originatingbody_name',
    'typedescription',
    'documentcollectionid=CHAMBER',
    'documentcollectionid=COMMITTEE',
    'documentcollectionid=GRANDCHAMBER']

# %%
dummy_df = pd.get_dummies(d,columns = cat_cols)
dummy_test = pd.get_dummies(t,columns = cat_cols)

# %%
dummy_df.shape
# Out:
# (8878, 325)

# %%
dummy_test.shape
# Out:
# (4760, 325)

# %%
np.unique(dummy_test.columns == dummy_df.columns)
# Out:
# array([ True])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
dummy_df.drop('judgementdate', axis=1, inplace=True)
dummy_test.drop('judgementdate', axis=1, inplace=True)

# %%
rf = RandomForestClassifier(bootstrap=False)

rf.fit(dummy_df, labels)
# Out:
# RandomForestClassifier(bootstrap=False)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'n_estimators':[50, 75, 100, 200],
         'max_depth':[4, 5, 6, 7],
         'criterion':['gini', 'entropy']}

# %%
cv = RandomizedSearchCV(rf, params)

# %%
cv.fit(dummy_df, labels)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(bootstrap=False),
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [4, 5, 6, 7],
#                                         'n_estimators': [50, 75, 100, 200]})

# %%
predictions = cv.predict(dummy_test)

# %%
p = predictions.astype(int)

# %%
t = pd.read_csv('test.csv', low_memory=False, parse_dates=['decisiondate', 'introductiondate', 'judgementdate', 'kpdate'])
t = t[['appno']]
t['importance'] =p# 0
t.to_csv('predictions2.csv', index=False)

# %%
started at 947

# %%
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)
# Out:
# Current Time = 21:49:06

# %%
cv.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=6, min_samples_split=75)
